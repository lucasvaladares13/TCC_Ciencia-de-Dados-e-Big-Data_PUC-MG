# %%
import pandas as pd
import datetime as dt
from _dictionary import (int_column,
                         time_id, 
                         col_dt_partida, 
                         col_dt_mandante, 
                         col_dt_visitante, 
                         col_dt_info, 
                         dict_dt_mandante,
                         dict_dt_visitante,
                         dict_dt_info
                            )

# %%
path = 'C:\\Users\\aci_d\\Documents\\Desenvolvimento\\01_Fut\\documentos\\PROCESSED\\01_SCRAP\\'
file = 'fbref_compiled_2022_02_15.xlsx'

# %%
df = pd.read_excel(path+file)
df
# Out:
#                mandante      visitante  m.Faltas  v.Faltas  m.Escanteios  \
# 0              Flamengo     AtlMineiro         7        10             4
# 1           Corinthians    Chapecoense        10        12             1
# 2            Fluminense         Santos        15        18             5
# 3             Palmeiras  Vasco-Da-Gama        19        16             3
# 4                 Bahia  AtlParanaense        11        11            14
# ...                 ...            ...       ...       ...           ...
# 3030  Brasil-De-Pelotas        Vitoria        19        18             5
# 3031            Guarani      Juventude        16        17             2
# 3032             Parana       Cruzeiro        12         9             6
# 3033            Nautico            CSA        22        16            10
# 3034        Chapecoense      Confianca        13        20             5
#
#       v.Escanteios  m.Cruzamentos  v.Cruzamentos  m.Contatos  v.Contatos  ...  \
# 0                6             21             15         537         701  ...
# 1                7             15             22         810         496  ...
# 2                8             27             21         483         684  ...
# 3                2             18             16         590         562  ...
# 4                3             30             10         487         669  ...
# ...            ...            ...            ...         ...         ...  ...
# 3030             4             25             12         568         544  ...
# 3031             6             19             20         682         452  ...
# 3032             1             10              7         670         668  ...
# 3033            12             21             40         539         545  ...
# 3034             4             24             21         553         559  ...
#
#       dia   ano  m.placar  v.placar  \
# 0      13  2017         1         1
# 1      13  2017         1         1
# 2      14  2017         3         2
# 3      14  2017         4         0
# 4      14  2017         6         2
# ...   ...   ...       ...       ...
# 3030   29  2021         0         1
# 3031   29  2021         0         1
# 3032   29  2021         0         0
# 3033   29  2021         1         1
# 3034   29  2021         3         1
#
#                                                    item  \
# 0     Campeonato Brasileiro Serie A (Rodada da seman...
# 1     Campeonato Brasileiro Serie A (Rodada da seman...
# 2     Campeonato Brasileiro Serie A (Rodada da seman...
# 3     Campeonato Brasileiro Serie A (Rodada da seman...
# 4     Campeonato Brasileiro Serie A (Rodada da seman...
# ...                                                 ...
# 3030  Campeonato Brasileiro Serie B (Rodada da seman...
# 3031  Campeonato Brasileiro Serie B (Rodada da seman...
# 3032  Campeonato Brasileiro Serie B (Rodada da seman...
# 3033  Campeonato Brasileiro Serie B (Rodada da seman...
# 3034  Campeonato Brasileiro Serie B (Rodada da seman...
#
#                                             file  m.Jogadasaéreas  \
# 0     2017-Serie-A-Resultados-e-Calendarios.xlsx                0
# 1     2017-Serie-A-Resultados-e-Calendarios.xlsx                0
# 2     2017-Serie-A-Resultados-e-Calendarios.xlsx                0
# 3     2017-Serie-A-Resultados-e-Calendarios.xlsx                0
# 4     2017-Serie-A-Resultados-e-Calendarios.xlsx                0
# ...                                          ...              ...
# 3030  2020-Serie-B-Resultados-e-Calendarios.xlsx                0
# 3031  2020-Serie-B-Resultados-e-Calendarios.xlsx                0
# 3032  2020-Serie-B-Resultados-e-Calendarios.xlsx                0
# 3033  2020-Serie-B-Resultados-e-Calendarios.xlsx                0
# 3034  2020-Serie-B-Resultados-e-Calendarios.xlsx                0
#
#       v.Jogadasaéreas  m.Cobrançadelateral  v.Cobrançadelateral
# 0                   0                    0                    0
# 1                   0                    0                    0
# 2                   0                    0                    0
# 3                   0                    0                    0
# 4                   0                    0                    0
# ...               ...                  ...                  ...
# 3030                0                    0                    0
# 3031                0                    0                    0
# 3032                0                    0                    0
# 3033                0                    0                    0
# 3034                0                    0                    0
#
# [3035 rows x 42 columns]

# %%
def create_partida_id(df):

    df = df.reset_index(drop =True)
    df['Partida_ID'] = df.index
    df['Partida_ID'] = df['Partida_ID'] + 1

    return df
def create_equipe_id(df,dict_id):
    
    df_id = pd.DataFrame(list(dict_id.items()), columns = ['Equipe','Equipe_ID'])
    df = pd.merge(df,df_id, how = 'left', left_on='mandante',right_on='Equipe')
    df = df.rename(columns={'Equipe':'m.Equipe','Equipe_ID':'m.Equipe_ID'})
    df = pd.merge(df,df_id, how = 'left', left_on='visitante',right_on='Equipe')
    df = df.rename(columns={'Equipe':'v.Equipe','Equipe_ID':'v.Equipe_ID'})
    

    return df

# %%
def dt_info(df, col, dict_info, path):
    file_name = 'dt_info.xlsx'
    dt = df[col].drop_duplicates()
    dt['mes_num'] = dt['mes'].replace(dict_info)
    dt['Data'] = dt['dia'].astype(str)+'/'+dt['mes_num'].astype(str)+'/'+dt['ano'].astype(str)
    print(dt['Data'])
    dt['Data'] = pd.to_datetime(dt['Data'])
    dt.to_excel(path+file_name, index = False)

def dt_partida(df,col,path):
    file_name = 'dt_partida.xlsx'
    dt = df[col].drop_duplicates()
    dt.to_excel(path+file_name, index = False)

def dt_time_sts(df,colm,dictm,colv,dictv,path):
    file_name = 'dt_time_sts.xlsx'
    dt_m = df[colm].rename(columns = dictm )
    dt_v = df[colv].rename(columns = dictv )
    dt = dt_m.append(dt_v)
    dt.to_excel(path+file_name, index = False)

def dt_time(dict_id,path):
    file_name = 'dt_time.xlsx'
    dt = pd.DataFrame(list(dict_id.items()), columns = ['Equipe','Equipe_ID'])
    dt.to_excel(path+file_name, index = False)

# %%
df = create_partida_id(df)
df = create_equipe_id(df,time_id)
df

# %%
path_DB = 'C:\\Users\\aci_d\\Documents\\Desenvolvimento\\01_Fut\\documentos\\DB_FUT\\'

# %%
dt_info(df,col_dt_info, dict_dt_info, path_DB)
dt_partida(df,col_dt_partida,path_DB)
dt_time_sts(df,col_dt_mandante,dict_dt_mandante,col_dt_visitante,dict_dt_visitante,path_DB)
dt_time(time_id,path_DB)
# Out:
# 0       13/05/2017
# 1       13/05/2017
# 2       14/05/2017
# 3       14/05/2017
# 4       14/05/2017
#            ...
# 3030    29/01/2021
# 3031    29/01/2021
# 3032    29/01/2021
# 3033    29/01/2021
# 3034    29/01/2021
# Name: Data, Length: 3035, dtype: object
